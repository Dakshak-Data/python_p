# %% [markdown]
# <a href="https://colab.research.google.com/github/Dakshak-Data/python_p/blob/main/python1_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
number = int(input('enter the number'))

digits = '0123456789'
result = ''
while number != 0:
  result = digits[number % 10] + result
  number = number//10

print(result)
# Out:
# enter the number2
# 2

# %%
L = [1,2,3,4]

sum = 0
for i in L:
  sum = sum + i

product = 1
for i in L:
  product = product*i

print(sum,product)
# Out:
# 10 24

# %%
A = [1,2,3,4]
B = [5,6,7,8]
for i in A:
  for j in B:
    print(i,j)
# Out:
# 1 5
# 1 6
# 1 7
# 1 8
# 2 5
# 2 6
# 2 7
# 2 8
# 3 5
# 3 6
# 3 7
# 3 8
# 4 5
# 4 6
# 4 7
# 4 8

# %%
A = [1,2,3,4]
B = [5,6,7,8]

for i in A:
  for j in B:
    for k in range(1000000):
      print(i,j)
# Out:
# Streaming output truncated to the last 5000 lines.
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# 1 5
# ...

# %%
L = [1,2,3,4,5]

for i in range(0,len(L)//2):
  other = len(L) - i -1
  temp = L[i]
  L[i] = L[other]
  L[other] = temp

print(L)
# Out:
# [5, 4, 3, 2, 1]

# %%
n = 10
k = 0;
for i in range(n//2,n):
  for j in range(2,n,pow(2,j)):
        k = k + n / 2;

print(k)
# Out:
# 35.0

# %%
a = 10
b = 3

if b <= 0:
  print(-1)
div = a//b

print(a-div-b)
# Out:
# 4

# %%
n = 345

sum = 0
while n>0:
  sum = sum + n%10
  n = n // 10

print(sum)

# %%
def fib(n):
  if n == 1 or n == 0:
    return 1
  else:
    return fib(n-1) + fib(n-2)

# %%
# Subset Algo

# %%
       {3T(n-1) if n>0
T(n) = {1, otherwise
# Out:
#   File "<ipython-input-9-a3b5bc01f042>", line 1
#     {3T(n-1) if n>0
#      ^
# SyntaxError: invalid decimal literal

# %%
       {2T(n-1)-1 if n>0
T(n) = {1, otherwise
